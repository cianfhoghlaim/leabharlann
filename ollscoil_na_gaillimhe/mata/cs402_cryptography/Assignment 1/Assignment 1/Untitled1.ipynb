# %%
import cs402

# %%
from cs402 import AffineCipher
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-4e5b5f0055f6> in <module>
# ----> 1 from cs402 import AffineCipher
#
# ImportError: cannot import name 'AffineCipher' from 'cs402' (unknown location)

# %%
from cs402 import AffineCipher
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-4e5b5f0055f6> in <module>
# ----> 1 from cs402 import AffineCipher
#
# ImportError: cannot import name 'AffineCipher' from 'cs402' (unknown location)

# %%
C=AffineCipher
C.setAlphabet=ALPHABET68
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9ca41cad678c> in <module>
# ----> 1 C=AffineCipher
#       2 C.setAlphabet=ALPHABET68
#
# NameError: name 'AffineCipher' is not defined
