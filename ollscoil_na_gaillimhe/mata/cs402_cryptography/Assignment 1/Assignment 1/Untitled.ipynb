# %%
import cs402 from "C:\Users\cianl\Anaconda3\Lib\site-packages\cs402"
# Out:
#   File "<ipython-input-5-edff7d704fa2>", line 1
#     import cs402 from "C:\Users\cianl\Anaconda3\Lib\site-packages\cs402"
#                     ^
# SyntaxError: invalid syntax

# %%
import cs402
from cs402 import AffineCipher
from cs402 import isEnglish
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-a65fcec4513e> in <module>
#       1 import cs402
# ----> 2 from cs402 import AffineCipher
#       3 from cs402 import isEnglish
#
# ImportError: cannot import name 'AffineCipher' from 'cs402' (unknown location)

# %%
import numpy

# %%
C=AffineCipher
C.setAlphabet=ALPHABET68

# %%
for a in range(1,68):
    for b in range(0,68):
        txt=C.decipher("a1q2-cipher6.txt")
        if isEnglish(txt):print(txt); print("A=" a, "B=" b)
