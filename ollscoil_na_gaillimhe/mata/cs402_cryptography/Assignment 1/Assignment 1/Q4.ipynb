# %%
import cs402
from cs402 import *
# Locate the file of ciphertext downloaded from assignment
file = open("C:\\Users\\cianl\\Downloads\\CS402\\Assignment 1\\a1q4-cipher1.txt") 

# Read the contents of the text file
CipherText = file.read()

# Use the string_to_int_list function from 'cs402.py' to convert the CipherText into
# the number each letter represents in the 68-symbol alphabet

CipherInt = string_to_int_list(ALPHABET27,CipherText)

# declare an Vigenere cipher using the 68 symbol alphabet
Q4=HigherAffineCipher(ALPHABET27, 2)

# %matplotlib inline 

frequency_histogram(CipherText)

digraph_ranking(CipherText, limit=10)

Q4.encrypt_string('KUFGMN', 'MATHEMATICAL')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e3613acdc12f> in <module>
#      10 # the number each letter represents in the 68-symbol alphabet
#      11
# ---> 12 CipherInt = string_to_int_list(ALPHABET27,CipherText)
#      13
#      14 # declare an Vigenere cipher using the 68 symbol alphabet
#
# NameError: name 'string_to_int_list' is not defined
